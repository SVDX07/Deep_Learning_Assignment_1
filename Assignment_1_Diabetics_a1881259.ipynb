# %%
import pandas as pd
import numpy as np
import requests
import csv

# Fetch the data
url = "https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/diabetes_scale"
df = pd.read_csv(url, sep = ' ', header = None)
df
# Out:
#      0             1             2             3            4            5  \
# 0   -1   1:-0.294118    2:0.487437    3:0.180328  4:-0.292929         5:-1
# 1    1   1:-0.882353   2:-0.145729   3:0.0819672  4:-0.414141         5:-1
# 2   -1  1:-0.0588235    2:0.839196   3:0.0491803         4:-1         5:-1
# 3    1   1:-0.882353   2:-0.105528   3:0.0819672  4:-0.535354  5:-0.777778
# 4   -1          1:-1    2:0.376884   3:-0.344262  4:-0.292929  5:-0.602837
# ..  ..           ...           ...           ...          ...          ...
# 763  1    1:0.176471   2:0.0150754    3:0.245902  4:-0.030303  5:-0.574468
# 764  1   1:-0.764706    2:0.226131    3:0.147541  4:-0.454545         5:-1
# 765  1   1:-0.411765     2:0.21608    3:0.180328  4:-0.535354  5:-0.735225
# 766 -1   1:-0.882353    2:0.266332  3:-0.0163934         4:-1         5:-1
# 767  1   1:-0.882353  2:-0.0653266    3:0.147541  4:-0.373737         5:-1
#
#                 6            7             8   9
# 0    6:0.00149028   7:-0.53117  8:-0.0333333 NaN
# 1     6:-0.207153  7:-0.766866   8:-0.666667 NaN
# 2     6:-0.305514  7:-0.492741   8:-0.633333 NaN
# 3     6:-0.162444  7:-0.923997          8:-1 NaN
# 4       6:0.28465   7:0.887276        8:-0.6 NaN
# ..            ...          ...           ...  ..
# 763   6:-0.019374  7:-0.920581         8:0.4 NaN
# 764   6:0.0968703   7:-0.77626        8:-0.8 NaN
# 765   6:-0.219076  7:-0.857387        8:-0.7 NaN
# 766   6:-0.102832  7:-0.768574   8:-0.133333 NaN
# 767  6:-0.0938897  7:-0.797609   8:-0.933333 NaN
#
# [768 rows x 10 columns]

# %%
df = pd.read_csv('diabetes_scale.csv', delimiter = '1:|2:|3:|4:|5:|6:|7:|8:', header = None, engine='python')
df
# Out:
#      0         1         2         3         4         5         6         7  \
# 0   -1 -0.294118  0.487437  0.180328 -0.292929 -1.000000  0.001490 -0.531170
# 1    1 -0.882353 -0.145729  0.081967 -0.414141 -1.000000 -0.207153 -0.766866
# 2   -1 -0.058824  0.839196  0.049180 -1.000000 -1.000000 -0.305514 -0.492741
# 3    1 -0.882353 -0.105528  0.081967 -0.535354 -0.777778 -0.162444 -0.923997
# 4   -1 -1.000000  0.376884 -0.344262 -0.292929 -0.602837  0.284650  0.887276
# ..  ..       ...       ...       ...       ...       ...       ...       ...
# 763  1  0.176471  0.015075  0.245902 -0.030303 -0.574468 -0.019374 -0.920581
# 764  1 -0.764706  0.226131  0.147541 -0.454545 -1.000000  0.096870 -0.776260
# 765  1 -0.411765  0.216080  0.180328 -0.535354 -0.735225 -0.219076 -0.857387
# 766 -1 -0.882353  0.266332 -0.016393 -1.000000 -1.000000 -0.102832 -0.768574
# 767  1 -0.882353 -0.065327  0.147541 -0.373737 -1.000000 -0.093890 -0.797609
#
#             8
# 0   -0.033333
# 1   -0.666667
# 2   -0.633333
# 3   -1.000000
# 4   -0.600000
# ..        ...
# 763  0.400000
# 764 -0.800000
# 765 -0.700000
# 766 -0.133333
# 767 -0.933333
#
# [768 rows x 9 columns]

# %%
df.head(10)
# Out:
#    0             1            2            3             4            5  \
# 0 -1   1:-0.294118   2:0.487437   3:0.180328   4:-0.292929         5:-1
# 1  1   1:-0.882353  2:-0.145729  3:0.0819672   4:-0.414141         5:-1
# 2 -1  1:-0.0588235   2:0.839196  3:0.0491803          4:-1         5:-1
# 3  1   1:-0.882353  2:-0.105528  3:0.0819672   4:-0.535354  5:-0.777778
# 4 -1          1:-1   2:0.376884  3:-0.344262   4:-0.292929  5:-0.602837
# 5  1   1:-0.411765   2:0.165829   3:0.213115          4:-1         5:-1
# 6 -1   1:-0.647059   2:-0.21608  3:-0.180328   4:-0.353535  5:-0.791962
# 7  1    1:0.176471   2:0.155779         3:-1          4:-1         5:-1
# 8 -1   1:-0.764706   2:0.979899   3:0.147541  4:-0.0909091   5:0.283688
# 9 -1  1:-0.0588235   2:0.256281    3:0.57377          4:-1         5:-1
#
#               6            7             8   9
# 0  6:0.00149028   7:-0.53117  8:-0.0333333 NaN
# 1   6:-0.207153  7:-0.766866   8:-0.666667 NaN
# 2   6:-0.305514  7:-0.492741   8:-0.633333 NaN
# 3   6:-0.162444  7:-0.923997          8:-1 NaN
# 4     6:0.28465   7:0.887276        8:-0.6 NaN
# 5    6:-0.23696  7:-0.894962        8:-0.7 NaN
# 6  6:-0.0760059  7:-0.854825   8:-0.833333 NaN
# 7    6:0.052161  7:-0.952178   8:-0.733333 NaN
# 8  6:-0.0909091  7:-0.931682   8:0.0666667 NaN
# 9          6:-1  7:-0.868488         8:0.1 NaN

# %%
df = df.drop(df.columns[9], axis=1)
df.head()
# Out:
#    0             1            2            3            4            5  \
# 0 -1   1:-0.294118   2:0.487437   3:0.180328  4:-0.292929         5:-1
# 1  1   1:-0.882353  2:-0.145729  3:0.0819672  4:-0.414141         5:-1
# 2 -1  1:-0.0588235   2:0.839196  3:0.0491803         4:-1         5:-1
# 3  1   1:-0.882353  2:-0.105528  3:0.0819672  4:-0.535354  5:-0.777778
# 4 -1          1:-1   2:0.376884  3:-0.344262  4:-0.292929  5:-0.602837
#
#               6            7             8
# 0  6:0.00149028   7:-0.53117  8:-0.0333333
# 1   6:-0.207153  7:-0.766866   8:-0.666667
# 2   6:-0.305514  7:-0.492741   8:-0.633333
# 3   6:-0.162444  7:-0.923997          8:-1
# 4     6:0.28465   7:0.887276        8:-0.6

# %%
df.iloc[:,0].value_counts()
# Out:
#  1    500
# -1    268
# Name: 0, dtype: int64

# %%
df = df.rename( columns= {0:'Outcome', 1:'Preganacies', 2:'Glucose', 3:'BloodPressure', 4:'SkinThickness',5:'Insulin',
                    6:'BMI', 7:'DiabetesPedFunc', 8:'Age'})

# %%
# See basic statistical details
df.describe()
# Out:
#           Outcome
# count  768.000000
# mean     0.302083
# std      0.953903
# min     -1.000000
# 25%     -1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
df.isnull().sum()
# Out:
# Outcome            0
# Preganacies        0
# Glucose            0
# BloodPressure      0
# SkinThickness      0
# Insulin            0
# BMI                0
# DiabetesPedFunc    0
# Age                9
# dtype: int64

# %%
df= df.dropna()
df
# Out:
#      Outcome   Preganacies       Glucose BloodPressure SkinThickness  \
# 0         -1   1:-0.294118    2:0.487437    3:0.180328   4:-0.292929
# 1          1   1:-0.882353   2:-0.145729   3:0.0819672   4:-0.414141
# 2         -1  1:-0.0588235    2:0.839196   3:0.0491803          4:-1
# 3          1   1:-0.882353   2:-0.105528   3:0.0819672   4:-0.535354
# 4         -1          1:-1    2:0.376884   3:-0.344262   4:-0.292929
# ..       ...           ...           ...           ...           ...
# 763        1    1:0.176471   2:0.0150754    3:0.245902   4:-0.030303
# 764        1   1:-0.764706    2:0.226131    3:0.147541   4:-0.454545
# 765        1   1:-0.411765     2:0.21608    3:0.180328   4:-0.535354
# 766       -1   1:-0.882353    2:0.266332  3:-0.0163934          4:-1
# 767        1   1:-0.882353  2:-0.0653266    3:0.147541   4:-0.373737
#
#          Insulin           BMI DiabetesPedFunc           Age
# 0           5:-1  6:0.00149028      7:-0.53117  8:-0.0333333
# 1           5:-1   6:-0.207153     7:-0.766866   8:-0.666667
# 2           5:-1   6:-0.305514     7:-0.492741   8:-0.633333
# 3    5:-0.777778   6:-0.162444     7:-0.923997          8:-1
# 4    5:-0.602837     6:0.28465      7:0.887276        8:-0.6
# ..           ...           ...             ...           ...
# 763  5:-0.574468   6:-0.019374     7:-0.920581         8:0.4
# 764         5:-1   6:0.0968703      7:-0.77626        8:-0.8
# 765  5:-0.735225   6:-0.219076     7:-0.857387        8:-0.7
# 766         5:-1   6:-0.102832     7:-0.768574   8:-0.133333
# 767         5:-1  6:-0.0938897     7:-0.797609   8:-0.933333
#
# [759 rows x 9 columns]

# %%
df.iloc[:,0].value_counts()
# Out:
#  1    496
# -1    263
# Name: Outcome, dtype: int64

# %%
y = pd.DataFrame(df.iloc[:,0])
x = df.iloc[:,1:]
x = x.to_numpy()
y = y.to_numpy()

# %%
from random import seed
from sklearn.model_selection import train_test_split

# %%
# Split dataset 80:20
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=20)

# %% [markdown]
# ## ``Method 1``

# %%
np.random.seed(20)
w = np.random.randn(9,1)* np.sqrt(1/1)
w
# Out:
# array([[ 0.88389311],
#        [ 0.19586502],
#        [ 0.35753652],
#        [-2.34326191],
#        [-1.08483259],
#        [ 0.55969629],
#        [ 0.93946935],
#        [-0.97848104],
#        [ 0.50309684]])

# %%
# predicts output given the rows and weights
def pred(row,w):
    # The first weight is always the bias
    atv = w[0]
    for i in range(len(row)):
        atv = atv + w[i+1]*row[i]
    return 1 if atv>=0 else -1

# %%
e = []
ss= []
def train(x_train, lrrate, epochs):
    for ep in range(epochs):
        global e 
        global ss 
        sum_square_error = 0
        for row, row1 in zip(x_train,y_train):
            prediction = pred(row,w)
            error = row1 - prediction
            w[0] = w[0] + lrrate*error
            sum_square_error = sum_square_error + ((error/2)**2)
            for i in range(len(row)):
                w[i+1]=w[i+1]+ lrrate*error*row[i]
        print('Epoch : {}'.format(ep),'\tError : {}'.format(sum_square_error))
        e.append(ep)
        ss.append(sum_square_error)
    return w

# %%
def perceptron(x_train, x_test, lrrate, epochs):
    weights=train(x_train, lrrate, epochs)
    pred1 = list()
    for row in x_test:
        predict = pred(row,weights)
        pred1.append(predict)
    return pred1

# %%
lrrate = 0.01
epochs = 100

# %%
def accuracy (pred, actual):
    right=0
    for i in range(len(pred)):
        if pred[i]==actual[i]:        
            right = right +1
    return right/len(pred) * 100

# %%
y_pred = perceptron(x_train, x_train, lrrate, epochs)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [20], in <module>
# ----> 1 y_pred = perceptron(x_train, x_train, lrrate, epochs)
#
# Input In [17], in perceptron(x_train, x_test, lrrate, epochs)
#       1 def perceptron(x_train, x_test, lrrate, epochs):
# ----> 2     weights=train(x_train, lrrate, epochs)
#       3     pred1 = list()
#       4     for row in x_test:
#
# Input In [16], in train(x_train, lrrate, epochs)
#       7 sum_square_error = 0
#       8 for row, row1 in zip(x_train,y_train):
# ----> 9     prediction = pred(row,w)
#      10     error = row1 - prediction
#      11     w[0] = w[0] + lrrate*error
#
# Input In [15], in pred(row, w)
#       4 atv = w[0]
#       5 for i in range(len(row)):
# ----> 6     atv = atv + w[i+1]*row[i]
#       7 return 1 if atv>=0 else -1
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('float64'), dtype('<U11')) -> None

# %%
acc = accuracy(y_train,y_pred)
print('Train Accuracy :', acc)
# Out:
# Train Accuracy : 76.44151565074135

# %%
y = perceptron(x_train, x_test, lrrate, epochs)
# Out:
# Epoch : 0 	Error : [184.]
# Epoch : 1 	Error : [177.]
# Epoch : 2 	Error : [186.]
# Epoch : 3 	Error : [193.]
# Epoch : 4 	Error : [190.]
# Epoch : 5 	Error : [180.]
# Epoch : 6 	Error : [188.]
# Epoch : 7 	Error : [176.]
# Epoch : 8 	Error : [195.]
# Epoch : 9 	Error : [189.]
# Epoch : 10 	Error : [179.]
# Epoch : 11 	Error : [207.]
# Epoch : 12 	Error : [180.]
# Epoch : 13 	Error : [186.]
# Epoch : 14 	Error : [185.]
# Epoch : 15 	Error : [181.]
# Epoch : 16 	Error : [177.]
# Epoch : 17 	Error : [186.]
# Epoch : 18 	Error : [181.]
# Epoch : 19 	Error : [186.]
# Epoch : 20 	Error : [188.]
# Epoch : 21 	Error : [175.]
# Epoch : 22 	Error : [178.]
# Epoch : 23 	Error : [182.]
# Epoch : 24 	Error : [193.]
# Epoch : 25 	Error : [182.]
# Epoch : 26 	Error : [192.]
# Epoch : 27 	Error : [174.]
# Epoch : 28 	Error : [184.]
# Epoch : 29 	Error : [193.]
# Epoch : 30 	Error : [183.]
# Epoch : 31 	Error : [186.]
# Epoch : 32 	Error : [180.]
# Epoch : 33 	Error : [182.]
# Epoch : 34 	Error : [182.]
# Epoch : 35 	Error : [192.]
# Epoch : 36 	Error : [192.]
# Epoch : 37 	Error : [180.]
# Epoch : 38 	Error : [174.]
# Epoch : 39 	Error : [188.]
# Epoch : 40 	Error : [192.]
# Epoch : 41 	Error : [190.]
# Epoch : 42 	Error : [206.]
# Epoch : 43 	Error : [194.]
# Epoch : 44 	Error : [200.]
# Epoch : 45 	Error : [184.]
# Epoch : 46 	Error : [188.]
# Epoch : 47 	Error : [189.]
# Epoch : 48 	Error : [186.]
# Epoch : 49 	Error : [193.]
# Epoch : 50 	Error : [187.]
# Epoch : 51 	Error : [179.]
# Epoch : 52 	Error : [184.]
# Epoch : 53 	Error : [187.]
# Epoch : 54 	Error : [201.]
# Epoch : 55 	Error : [190.]
# Epoch : 56 	Error : [192.]
# Epoch : 57 	Error : [176.]
# Epoch : 58 	Error : [183.]
# Epoch : 59 	Error : [199.]
# Epoch : 60 	Error : [180.]
# Epoch : 61 	Error : [192.]
# Epoch : 62 	Error : [184.]
# Epoch : 63 	Error : [183.]
# Epoch : 64 	Error : [183.]
# Epoch : 65 	Error : [188.]
# Epoch : 66 	Error : [180.]
# Epoch : 67 	Error : [190.]
# Epoch : 68 	Error : [192.]
# Epoch : 69 	Error : [192.]
# Epoch : 70 	Error : [188.]
# Epoch : 71 	Error : [194.]
# Epoch : 72 	Error : [188.]
# Epoch : 73 	Error : [196.]
# Epoch : 74 	Error : [200.]
# Epoch : 75 	Error : [183.]
# Epoch : 76 	Error : [183.]
# Epoch : 77 	Error : [186.]
# Epoch : 78 	Error : [184.]
# Epoch : 79 	Error : [180.]
# Epoch : 80 	Error : [194.]
# Epoch : 81 	Error : [180.]
# Epoch : 82 	Error : [180.]
# Epoch : 83 	Error : [199.]
# Epoch : 84 	Error : [187.]
# Epoch : 85 	Error : [190.]
# Epoch : 86 	Error : [188.]
# Epoch : 87 	Error : [186.]
# Epoch : 88 	Error : [175.]
# Epoch : 89 	Error : [189.]
# Epoch : 90 	Error : [190.]
# Epoch : 91 	Error : [194.]
# Epoch : 92 	Error : [198.]
# Epoch : 93 	Error : [185.]
# Epoch : 94 	Error : [187.]
# Epoch : 95 	Error : [196.]
# Epoch : 96 	Error : [176.]
# Epoch : 97 	Error : [185.]
# Epoch : 98 	Error : [184.]
# Epoch : 99 	Error : [193.]

# %%
from matplotlib import pyplot as plt
plt.plot(e,ss)
plt.xlabel('Epochs')
plt.ylabel('Sum of squared error')
# Out:
# Text(0, 0.5, 'Sum of squared error')

# %%
len(y)
# Out:
# 152

# %%
acc = accuracy(y_test,y)
print('Test Accuracy :', acc)
# Out:
# Test Accuracy : 72.36842105263158

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
cn = confusion_matrix(y_test, y)

# %%
print('classification report \n',classification_report(y_test, y))
# Out:
# classification report
#                precision    recall  f1-score   support
#
#           -1       0.73      0.39      0.51        56
#            1       0.72      0.92      0.81        96
#
#     accuracy                           0.72       152
#    macro avg       0.73      0.65      0.66       152
# weighted avg       0.73      0.72      0.70       152

# %%
from sklearn.metrics import precision_recall_fscore_support as sc

# %%
precision,recall,f1,support = sc(y_test, y)
print('precision for both classes: {}'.format(precision))
print('recall for both classes: {}'.format(recall))
print('f1score for both classes: {}'.format(f1))
# Out:
# precision for both classes: [0.73333333 0.72131148]
# recall for both classes: [0.39285714 0.91666667]
# f1score for both classes: [0.51162791 0.80733945]

# %% [markdown]
# ## ``Method 2``

# %%
# Xavier initialization
np.random.seed(20)
w = np.random.randn(9,1)* ((1/8)**0.5)
w
# Out:
# array([[ 0.31250341],
#        [ 0.06924874],
#        [ 0.12640825],
#        [-0.82846819],
#        [-0.38354624],
#        [ 0.19788252],
#        [ 0.33215257],
#        [-0.34594529],
#        [ 0.17787159]])

# %%
# predicts output given the rows and weights
def pred(row,w):
    # The first weight is always the bias
    atv = w[0]
    for i in range(len(row)):
        atv = np.tanh(atv + w[i+1]*row[i])
    return 1 if atv>=0 else -1

# %%
e = []
ss= []
def train(x_train, lrrate, epochs):
    for ep in range(epochs):
        global e 
        global ss
        sum_square_error = 0
        for row, row1 in zip(x_train,y_train):
            prediction = pred(row,w)
            error = row1 - prediction
            sum_square_error = sum_square_error + ((error/2)**2)
            for i in range(len(row)):
                der = 1-(np.tanh((w[0] + w[i+1]*row[i])))**2
                w[i+1]=w[i+1]+ lrrate*error*row[i]*der
            w[0] = w[0] + lrrate*error*der
        print('Epoch : {}'.format(ep),'\tError : {}'.format(sum_square_error))
        e.append(ep)
        ss.append(sum_square_error)
    return w

# %%
def perceptron(x_train, x_test, lrrate, epochs):
    weights=train(x_train, lrrate, epochs)
    pred1 = list()
    for row in x_test:
        predict = pred(row,weights)
        pred1.append(predict)
    return pred1

# %%
lrrate = 0.01
epochs = 500

# %%
def accuracy (pred, actual):
    right=0
    for i in range(len(pred)):
        if pred[i]==actual[i]:        
            right = right +1
    return right/len(pred) * 100

# %%
y_pred = perceptron(x_train, x_train, lrrate, epochs)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [24], in <module>
# ----> 1 y_pred = perceptron(x_train, x_train, lrrate, epochs)
#
# Input In [21], in perceptron(x_train, x_test, lrrate, epochs)
#       1 def perceptron(x_train, x_test, lrrate, epochs):
# ----> 2     weights=train(x_train, lrrate, epochs)
#       3     pred1 = list()
#       4     for row in x_test:
#
# Input In [20], in train(x_train, lrrate, epochs)
#       7 sum_square_error = 0
#       8 for row, row1 in zip(x_train,y_train):
# ----> 9     prediction = pred(row,w)
#      10     error = row1 - prediction
#      11     sum_square_error = sum_square_error + ((error/2)**2)
#
# Input In [19], in pred(row, w)
#       4 atv = w[0]
#       5 for i in range(len(row)):
# ----> 6     atv = np.tanh(atv + w[i+1]*row[i])
#       7 return 1 if atv>=0 else -1
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('float64'), dtype('<U11')) -> None
